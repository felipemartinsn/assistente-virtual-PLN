# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemartinsn/assistente-virtual-PLN/blob/main/assistente_virtual_pln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação das bibliotecas necessárias
# !apt-get install espeak
# !pip install gTTS SpeechRecognition PyDub
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# espeak is already the newest version (1.48.15+dfsg-3).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
# Importações
import os
import speech_recognition as sr
from gtts import gTTS
from IPython.display import Audio
from google.colab import files

# %%
# Módulo 1: Transformação de texto em áudio (Text to Speech)
def text_to_speech(text):
    tts = gTTS(text=text, lang='pt')
    tts.save("response.mp3")
    return Audio("response.mp3", autoplay=True)

# Módulo 2: Transformação de fala em texto (Speech to Text) usando um arquivo de áudio
def speech_to_text():
    recognizer = sr.Recognizer()

    # Faz upload de um arquivo de áudio .wav
    uploaded = files.upload()

    for filename in uploaded.keys():
        with sr.AudioFile(filename) as source:
            audio = recognizer.record(source)
            try:
                text = recognizer.recognize_google(audio, language="pt-BR")
                print("Você disse: " + text)
                return text.lower()
            except sr.UnknownValueError:
                print("Não entendi o que você disse. Tente novamente.")
                return ""
            except sr.RequestError:
                print("Erro ao conectar com o serviço de reconhecimento de fala.")
                return ""

# Funções automatizadas
def executar_comando(comando):
    if "abrir google" in comando:
        text_to_speech("Abrindo o Google.")
        os.system("xdg-open https://www.google.com")
    elif "pesquisar por" in comando:
        termo = comando.replace("pesquisar por", "").strip()
        text_to_speech(f"Pesquisando por {termo} no Google.")
        os.system(f"xdg-open https://www.google.com/search?q={termo}")
    else:
        text_to_speech("Comando não reconhecido. Tente novamente.")

# %%
# Loop principal
if __name__ == "__main__":
    text_to_speech("Assistente virtual iniciada. Por favor, faça upload de um arquivo de áudio.")
    comando = speech_to_text()
    if comando:
        executar_comando(comando)
# Out:
#      <input type="file" id="files-50c8ed4a-4831-4002-961c-5979b04937e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50c8ed4a-4831-4002-961c-5979b04937e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
